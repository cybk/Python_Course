# %%
# Tuples
colors = ("red", "yellow", "green")
colors

for color in colors:
    print("color is: " + color)
# Out:
# color is: red
# color is: yellow
# color is: green

# %%
colors[2]
# Out:
# 'green'

# %%
# Exercise 01
lst = [1,2,5,25,33,56,75,21,56,89,43,13,62,24]
if (21 in lst):
    print("Operator {} is on the list".format(21))
else:
    print("Operator not in the list")
# Out:
# Operator 21 is on the list

# %%
# Exercise 02
tup = ("Antonio", "Pedro", "Maria")
tup
data = input()
if (data in tup):
    print("{} is on the tuple".format(data))
else:
    print("{} is NOT on the tuple".format(data))
# Out:
#  pedro
# pedro is NOT on the tuple

# %%
# Exercise 03
some = {1,2,3,4,5}
some
some.add(6)
some
some.add(7)
some.add(8)
some.add(9)
some.remove(9)
some
type(some)
# Out:
# set

# %%
dict = {"uno":"one", "dos":"two", "tres": "three"}
dict
# Out:
# {'uno': 'one', 'dos': 'two', 'tres': 'three'}

# %%
dict["cuatro"] = "four"
dict
# Out:
# {'uno': 'one', 'dos': 'two', 'tres': 'three', 'cuatro': 'four'}

# %%
dict["dato"] = input()
dict
