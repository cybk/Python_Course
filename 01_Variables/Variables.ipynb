# %%
# Numbers
numero1 = 5
print("numero: " +  str(numero1))
# Out:
# numero: 5

# %%
numero1
# Out:
# 5

# %%
numDecimal = 3.5
type(numDecimal)
# Out:
# float

# %%
print ("Suma: " + str(numero1 + numDecimal))
# Out:
# Suma: 8.5

# %%
#Exercise 1
numero1 = 5
print('type numero1: ' + str(type(numero1)) + '\n')

numero2 = 6.5
print('tupe numero2: ' + str(type(numero2)) + '\n')

numero3 = 7
print('type numero3: ' + str(type(numero3)) + '\n')

suma = numero1 + numero2 + numero3
print('Suma: ' + str(suma))
print('Type suma: ' + str(type(suma)))
# Out:
# type numero1: <class 'int'>
#
# tupe numero2: <class 'float'>
#
# type numero3: <class 'int'>
#
# Suma: 18.5
# Type suma: <class 'float'>

# %%
#Exercise 2
numero1 = 5
numero2 = 3
suma = numero1 + numero2
strSuma = str(suma)
strResultado = 'The result is: ' + strSuma
print(strResultado)
# Out:
# The result is: 8

# %%
# Strings
Cadena = "Hola Mundo"
Cadena
# Out:
# 'Hola Mundo'

# %%
Cadena[5]
# Out:
# 'M'

# %%
Cadena[-1]
# Out:
# 'o'

# %%
Cadena[2:9]
# Out:
# 'la Mund'

# %%
Cadena[3:]
# Out:
# 'a Mundo'

# %%
#String methods
initial = 'Hola Mundo'

len(initial)
# Out:
# 10

# %%
initial.upper()
# Out:
# 'HOLA MUNDO'

# %%
initial.lower()
# Out:
# 'hola mundo'

# %%
initial.split(' ')
# Out:
# ['Hola', 'Mundo']

# %%
name = 'Fulanito'
age = 18

print('My name is {}, and my age is {}'.format(name, age))
# Out:
# My name is Fulanito, and my age is 18

# %%
some = 10/3
some
# Out:
# 3.3333333333333335

# %%
print('The result is: {r:1.3f}'.format(r=some))
# Out:
# The result is: 3.333

# %%
#-input by keyboard
print("Add your name")
nameAdded = input()
print("Your name is: " + nameAdded)
# Out:
# Add your name
#  Cybk
# Your name is: Cybk

# %%
#Exercise 1
ex1 = "Esto es un texto de ejemplo"
ex1[11:16]
# Out:
# 'texto'

# %%
#Exercise 2
exLength = len(ex1)
exLength
strLength = str(exLength)
up = ex1.upper()
result2 = "The strins \"" + up + "\" has a length of: " + strLength
result2
# Out:
# 'The strins "ESTO ES UN TEXTO DE EJEMPLO" has a length of: 27'

# %%
# Exercise3
number1 = 5
number2 = 8
sumResult = number1 + number2
print("Result {} + {} is: {}".format(number1, number2, sumResult))
# Out:
# Result 5 + 8 is: 13

# %%
# Exercise 4
print("Write the first number: ")
num1 = input()
print("Write the second number: ")
num2 = input()
sumResult = int(num1) + int(num2)
strResult = str(sumResult)
print("The result of sum both numbers is: " + strResult)
# Out:
# Write the first number:
#  18
# Write the second number:
#  23
# The result of sum both numbers is: 41
