# %%
# Exercise 01
values = {"manzana":"apple", "naranja":"orange", "platano":"banana", "limon":"lemon"}

# %%
values["naranja"]
# Out:
# 'orange'

# %%
values["piña"] = "pineapple"

# %%
values
# Out:
# {'manzana': 'apple',
#  'naranja': 'orange',
#  'platano': 'banana',
#  'limon': 'lemon',
#  'piña': 'pineapple'}

# %%
for e in values:
    print("element: '{}' has translation: '{}'".format(e, values[e]))
# Out:
# element: 'manzana' has translation: 'apple'
# element: 'naranja' has translation: 'orange'
# element: 'platano' has translation: 'banana'
# element: 'limon' has translation: 'lemon'
# element: 'piña' has translation: 'pineapple'

# %%
# Exercise 02
note = 4.5
work_done = "yes"
final_note = "failed"
if note >= 4 and work_done == "yes":
    final_note = "Passed"

print("Course result: '{}'".format(final_note))
# Out:
# Course result: 'Passed'

# %%
# Exercise 03
start = 1
end = 6
while start < end:
    print("This is the line: '{}'".format(start))
    start += 1
# Out:
# This is the line: '1'
# This is the line: '2'
# This is the line: '3'
# This is the line: '4'
# This is the line: '5'
