# %%
import file_module

filename = "fl_ex.txt"

file_op = file_module.fl(filename)

# %%
text = "Fer was skinny and kind of short, but \n She was attractive in his own way"
file_op.saveFile(text)

# %%
text = "\n She surely was pretty flexible on bed, and should has a cute ass"
file_op.appendFile(text)

# %%
text = file_op.readFile()
text
# Out:
# 'Fer was skinny and kind of short, but \n She was attractive in his own wayShe surely was pretty flexible on bed, and should has a cute ass'
