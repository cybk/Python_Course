# %%
fl1 = open("File1.txt", "rt")
data = fl1.read()

print(data)
# Out:
# This is a text file
# with two lines of text

# %%
# Save into a file
fl2 = open("file_record.txt", "wt")

data_string = "This a recorded Text, I want to put my tongue just on the middle of Monz' Ass"
fl2.write(data_string)
fl2.close()

# %%
with open("file_record.txt", "at") as fl3:
    data_to_add = "\n and for sure she should do really great blowjobs"
    fl3.write(data_to_add)

# %%
import os
os.remove("file_record.txt")
